# %%
import pandas as pd
import numpy as np
ser1 = pd.Series(list('abcedfghijklmnopqrstuvwxyz'))
ser2 = pd.Series(np.arange(26))

# Solution 1 
df = pd.concat([ser1, ser2], axis=1) 
# Solution 2 
df = pd.DataFrame({'col1': ser1, 'col2': ser2}) 
print(df.head())
# Out:
#   col1  col2
# 0    a     0
# 1    b     1
# 2    c     2
# 3    e     3
# 4    d     4

# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd

df1 = pd.read_csv('pokemon_data.csv')

#df.head(5)
df = pd.read_excel('modified.xlsx')

#df.to_excel('modified.xlsx', index=False)
#df.to_csv('modified.txt', index=False, sep='z')

#print(df.head(5))
df.head(5)

df[['Name']]
# df = pd.read_excel('modified.xlsx')
#df
# print(df_xlsx.head(3))

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')

# print(df.head(5))

# df[['HP']]
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %% [markdown]
# ## Reading Data in Pandas

# %%
#### Read Headers
#df.columns

## Read each Column
#df[['Name', 'Type 1', 'HP']]

## Read Each Row
#df.iloc[0:4, 3:5]
#print(df.iloc[0:4])

#for index, row in df.iterrows():
#    print(row['Name'], '  ', row['HP'])
    
#df1 = df.loc[(df['Type 1'] == "Grass") & (df['HP'] > 80) & (df['HP'] < 100)]
#df1.head(5)

#df.head(5)
## Read a specific location (R,C)
print(df.iloc[2,1])
# Out:
# Venusaur

# %% [markdown]
# ## Sorting/Describing Data

# %%
#df.sort_values('HP', ascending=0)
#df
#df.sort_values(['Type 1', 'HP'], ascending=[1,0])

# describing data
df.describe()

#df
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ## Making changes to the data

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#df = df.drop(columns=['Total'])

#df['Hp+Attack'] = df.iloc[:, 4:6].sum(axis=1)

cols = list(df.columns)
print(cols)

df = df[cols[0:4] + [cols[-1]] + cols[4:13]]

df.head(5)
#45+49+49+65+65+45
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total', 'Hp+Attack']
#    #                   Name Type 1  Type 2  Hp+Attack  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison         94  45      49       49
# 1  2                Ivysaur  Grass  Poison        122  60      62       63
# 2  3               Venusaur  Grass  Poison        162  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison        180  80     100      123
# 4  4             Charmander   Fire     NaN         91  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0       65       65     45           1      False    318
# 1       80       80     60           1      False    405
# 2      100      100     80           1      False    525
# 3      122      120     80           1      False    625
# 4       60       50     65           1      False    309

# %%
45+49+49+65+65+45
# Out:
# 318

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
# df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

# df.to_csv('modified.txt', index=False, sep='\t')

dir(df)
# Out:
# ['Attack',
#  'Defense',
#  'Generation',
#  'HP',
#  'Legendary',
#  'Name',
#  'Speed',
#  'T',
#  'Total',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
# ...

# %% [markdown]
# ## Filtering Data

# %%
#new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

#new_df.reset_index(drop=True, inplace=True)

#new_df

#new_df.to_csv('filtered.csv')

#############################################

#df.loc[df.Name.str.contains('Mega')]

# If you want to use not its actually ~

#df.loc[~df.Name.str.contains('Mega')]

#Lets try this with a regular expression

import re

df.loc[df.Name.str.contains('Char[a-]', regex=True)]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Hp+Attack, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, Total]
# Index: []

# %% [markdown]
# ## Conditional Changes

# %%
df1 = df1.loc[df1['Speed'] > 50, ['Generation','Legendary']] = ['Test 1', 'Test 2']

# df

#df = pd.read_csv('modified.csv')

df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12712/3412031044.py in <module>
# ----> 1 df1 = df1.loc[df1['Speed'] > 50, ['Generation','Legendary']] = ['Test 1', 'Test 2']
#       2
#       3 # df
#       4
#       5 #df = pd.read_csv('modified.csv')
#
# AttributeError: 'list' object has no attribute 'loc'

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %%
df = pd.read_csv('modified.csv')

df['count'] = 1

df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
#                       ..
# Rock      Fighting     1
#           Flying       4
#           Grass        2
#           Ground       6
#           Ice          2
# ...

# %% [markdown]
# ## Working with large amounts of data

# %%
#new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('pokemon_data.csv', chunksize=10):
    results = df.groupby(['Type 1']).count()

    
print(results)
    #new_df = pd.concat([new_df, results])
# Out:
#          #  Name  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Dark     1     1       1   1       1        1        1        1      1
# Dragon   1     1       1   1       1        1        1        1      1
# Fairy    1     1       0   1       1        1        1        1      1
# Fire     1     1       1   1       1        1        1        1      1
# Flying   2     2       2   2       2        2        2        2      2
# Psychic  2     2       2   2       2        2        2        2      2
# Rock     2     2       2   2       2        2        2        2      2
#
#          Generation  Legendary
# Type 1
# Dark              1          1
# Dragon            1          1
# Fairy             1          1
# Fire              1          1
# Flying            2          2
# Psychic           2          2
# Rock              2          2
